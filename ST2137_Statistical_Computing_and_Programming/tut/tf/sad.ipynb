# %%
import pandas as pd

# %%
res = pd.read_csv("2026-04-25T0933_Grades-CS2030S.csv")

res["PE1 (250690)"].plot(kind="hist")

res["PE1 (250690)"].describe()
# Out:
# count    669.000000
# mean      11.715441
# std        5.026317
# min        0.000000
# 25%        8.800000
# 50%       11.500000
# 75%       15.000000
# max       30.000000
# Name: PE1 (250690), dtype: float64
